# %% [markdown]
# # Cleaning Maryland Data
# Mary Glantz
# Data 205

# %%
import json
import numpy as np
import pandas as pd
import requests

# %%
mdcrashdf = pd.DataFrame(requests.get('https://opendata.maryland.gov/resource/65du-s3qu.json').json())
mdcrashdf.head()
# Out:
#    year quarter light_desc light_code     county_desc county_no  \
# 0  2020      Q2   Daylight          1       Baltimore         3
# 1  2020      Q2        NaN       6.02  Baltimore City        24
# 2  2020      Q2   Daylight          1      Montgomery        15
# 3  2017      Q2   Daylight          1  Baltimore City        24
# 4  2020      Q2   Daylight          1           Cecil         7
#
#        collision_type_desc collision_type_code    fix_obj_desc fix_obj_code  \
# 0                    Other                  88  Not Applicable            0
# 1                    Other                  88      Other Pole           10
# 2                    Other                  88  Not Applicable            0
# 3           Single Vehicle                  17  Not Applicable            0
# 4  Same Direction Rear End                   3  Not Applicable            0
#
#    ... reference_road_name muni_code rte_no route_type_code  \
# ...

# %%
mdcrashdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 56 columns):
# year                           1000 non-null object
# quarter                        1000 non-null object
# light_desc                     949 non-null object
# light_code                     1000 non-null object
# county_desc                    1000 non-null object
# county_no                      1000 non-null object
# collision_type_desc            1000 non-null object
# collision_type_code            1000 non-null object
# fix_obj_desc                   915 non-null object
# fix_obj_code                   1000 non-null object
# report_no                      1000 non-null object
# report_type                    999 non-null object
# weather_desc                   260 non-null object
# weather_code                   1000 non-null object
# acc_date                       1000 non-null object
# acc_time                       1000 non-null object
# ...

# %%
mdcrashdf['year'] = pd.to_datetime(mdcrashdf['year'])
mdcrashdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 56 columns):
# year                           1000 non-null datetime64[ns]
# quarter                        1000 non-null object
# light_desc                     949 non-null object
# light_code                     1000 non-null object
# county_desc                    1000 non-null object
# county_no                      1000 non-null object
# collision_type_desc            1000 non-null object
# collision_type_code            1000 non-null object
# fix_obj_desc                   915 non-null object
# fix_obj_code                   1000 non-null object
# report_no                      1000 non-null object
# report_type                    999 non-null object
# weather_desc                   260 non-null object
# weather_code                   1000 non-null object
# acc_date                       1000 non-null object
# acc_time                       1000 non-null object
# ...

# %%
county_desc = mdcrashdf.county_desc
county_desc_uniques = county_desc.unique()
county_desc_uniques
# Out:
# array(['Baltimore', 'Baltimore City', 'Montgomery', 'Cecil',
#        'Anne Arundel', 'Frederick', "Prince George's", 'Talbot',
#        'Harford', 'Kent', 'Wicomico', "Queen Anne's", 'Worcester',
#        'Carroll', 'Howard', 'Charles', 'Garrett', 'Dorchester', 'Calvert',
#        'Washington', "St. Mary's", 'Allegany', 'Somerset', 'Caroline'],
#       dtype=object)

# %%
pgcrash = mdcrashdf.loc[mdcrashdf['county_desc']=='Prince George\'s' ]

# %%
pgcrash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 12 to 990
# Data columns (total 56 columns):
# year                           161 non-null datetime64[ns]
# quarter                        161 non-null object
# light_desc                     157 non-null object
# light_code                     161 non-null object
# county_desc                    161 non-null object
# county_no                      161 non-null object
# collision_type_desc            161 non-null object
# collision_type_code            161 non-null object
# fix_obj_desc                   150 non-null object
# fix_obj_code                   161 non-null object
# report_no                      161 non-null object
# report_type                    161 non-null object
# weather_desc                   36 non-null object
# weather_code                   161 non-null object
# acc_date                       161 non-null object
# acc_time                       161 non-null object
# ...

# %%
fredcrash = mdcrashdf.loc[mdcrashdf['county_desc']=='Frederick']
fredcrash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 6 to 992
# Data columns (total 56 columns):
# year                           21 non-null datetime64[ns]
# quarter                        21 non-null object
# light_desc                     18 non-null object
# light_code                     21 non-null object
# county_desc                    21 non-null object
# county_no                      21 non-null object
# collision_type_desc            21 non-null object
# collision_type_code            21 non-null object
# fix_obj_desc                   18 non-null object
# fix_obj_code                   21 non-null object
# report_no                      21 non-null object
# report_type                    21 non-null object
# weather_desc                   3 non-null object
# weather_code                   21 non-null object
# acc_date                       21 non-null object
# acc_time                       21 non-null object
# ...

# %%
fredcrash.head()
# Out:
#           year quarter light_desc light_code county_desc county_no  \
# 6   2020-01-01      Q2   Daylight          1   Frederick        10
# 74  2020-01-01      Q2   Daylight          1   Frederick        10
# 204 2020-01-01      Q2        NaN       6.02   Frederick        10
# 225 2020-01-01      Q2   Daylight          1   Frederick        10
# 332 2020-01-01      Q2   Daylight          1   Frederick        10
#
#      collision_type_desc collision_type_code        fix_obj_desc fix_obj_code  \
# 6    Same Movement Angle                  11      Not Applicable            0
# 74        Single Vehicle                  17      Tree Shrubbery           11
# 204       Single Vehicle                  17                 NaN        22.03
# 225    Head On Left Turn                   2      Not Applicable            0
# 332       Single Vehicle                  17  Light Support Pole            8
#
#      ... reference_road_name muni_code rte_no route_type_code  \
# ...
